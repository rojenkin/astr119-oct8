# %%
x = 3

# %%
x
# Out:
# 3

# %%
import numpy as np
import numpy

# %%
type(numpy.array)
# Out:
# builtin_function_or_method

# %%
x = 4
print(x)
def func(y):
    x = 5
    print(x)
    print(y)
    
func(7)
print(x)
def func(y):
    global x
    x = 5
    print(x)
    print(y)
    
func(7)
print(x)
# Out:
# 4
# 5
# 7
# 4
# 5
# 7
# 5

# %%
x ** 4
# Out:
# 625

# %%
x ^ 4
# Out:
# 1

# %%
np.power(x, 4)
# Out:
# 625

# %%
def func1()
# Out:
#   File "<ipython-input-17-7f48491a5e09>", line 1
#     def func1()
#                ^
# SyntaxError: invalid syntax

# %%
def funcl():
    return 5

# %%
funcl()
# Out:
# 5

# %%
funcl
# Out:
# <function __main__.funcl()>

# %%
def func2():
    return 5, 6

# %%
type(funcl())
# Out:
# int

# %%
type(func2)
# Out:
# function

# %%
type(func2())
# Out:
# tuple

# %%
def func3():
    return list(func2())

# %%
func3()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-b7e4f488dc81> in <module>()
# ----> 1 func3()
#
# <ipython-input-25-a9fa257eda3e> in func3()
#       1 def func3():
# ----> 2     return list(5,6)
#
# TypeError: list() takes at most 1 argument (2 given)

# %%
func3()
# Out:
# [5, 6]

# %%
func2()
# Out:
# (5, 6)

# %%
funcl()
# Out:
# 5

# %%
x = (5,6)

# %%
x[0]
# Out:
# 5

# %%
x[0] = 7
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-6d0ccf279659> in <module>()
# ----> 1 x[0] = 7
#
# TypeError: 'tuple' object does not support item assignment

# %%
list(x)
# Out:
# [5, 6]

# %%
type(list(x))
# Out:
# list

# %%
y = list(x)

# %%
y[0] =7

# %%
y
# Out:
# [7, 6]

# %%
y = [7, 6.0, 'a', np.array]

# %%
y[3]
# Out:
# <function numpy.core.multiarray.array>

# %%
print("Hello")
# Out:
# Hello

# %%
type(x)
# Out:
# tuple

# %%
np.shape(x)
# Out:
# (2,)

# %%
type(x)
# Out:
# tuple
